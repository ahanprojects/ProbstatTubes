# %%
# Soal 2

# Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap
# kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot
# tersebut.

import pandas as pd
import matplotlib.pyplot as plt

# membuka file csv
path = 'D:\KULIAH SMT 4\IF2220 Probabilitas dan Statistika\TUBES\Gandum.csv'
# menamakan kolom
df = pd.read_csv(path, names=["id", "Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir", "Keliling", "Bulatan", "Ransum", "Kelas"])

# %%
# Daerah
titl = "Daerah"
print("Histogram :")
df.Daerah.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column="Daerah")
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# SumbuUtama
titl = "SumbuUtama"
print("Histogram :")
df.SumbuUtama.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column="Daerah")
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# SumbuKecil
titl = "SumbuKecil"
print("Histogram :")
df.SumbuKecil.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Keunikan
titl = "Keunikan"
print("Histogram :")
df.Keunikan.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Area Bulatan
titl = "AreaBulatan"
print("Histogram :")
df.AreaBulatan.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Diameter
titl = "Diameter"
print("Histogram :")
df.Diameter.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Kadar Air
titl = "Daerah"
print("Histogram :")
df.KadarAir.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Keliling
titl = "Daerah"
print("Histogram :")
df.Keliling.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Bulatan
titl = "Bulatan"
print("Histogram :")
df.Bulatan.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Ransum
titl = "Ransum"
print("Histogram :")
df.Ransum.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....

# %%
# Kelas
titl = "Kelas"
print("Histogram :")
df.Kelas.plot(kind='hist',edgecolor='black', color='skyblue', title="Histogram "+titl, grid=True)
plt.show()
print("Boxplot :")
df.boxplot(column=titl)
plt.show()

a = "uraian disini ...."
print(a)
# Out:
# Histogram :
# Boxplot :
# uraian disini ....
